# %%
class tcs:
    def __init__(self):
        print('WELCOME TO CRAKE TCS 2022 CODING QUESTION IN PYTHON')
        
    def check_prime(self):
        x = int(input('enter a number to check prime number : '))
        flag = True
        for i in range(3,x):
            if x%i==0:
                flag = False
            else:
                continue
        if flag:
            return 'prime number'
        else:
            return 'not prime'
        
    def check_pallindrom(self,x):
        #x = input('enter a number to check that number is pallindrom or not')
        if str(x) == str(x)[::-1]:
            return 'pallindrom number'
        else:
            return 'not pallindrom'
        
        
    def check_perfect(self):
        x = int(input('enter a number to check that number is perfect or not'))
        sum = 0
        for i in range(1,x):
            if x%i == 0:
                sum += i
            else:
                continue
        if sum == x:
            return 'perfect number'
        else:
            return 'not perfect number'
        
    def check_strong(self):
        x = int(input('enter a number to check that number is strong or not'))
        sum = 0
        for i in str(x):
            y = self.factorial(int(i))
            sum += y
        print(sum)
        if sum == x:
            return 'strong number'
        else:
            return 'not strong number'
            
            
    def factorial(self,x):
        if(x==1 or x==0):
            return 1
        else:
            return x*factorial(x-1)
        
    
    def check_armstrong(self):
        x = int(input('enter a number to check that number is armstrong or not'))
        sum = 0
        for i in str(x):
            sum += int(i)**3
        if x == sum:
            return 'armstrong'
        else:
            return 'not armstrong'
        
        
    def digit_count(self):
        x = int(input('enter a number to count digit'))
        count = 0
        for i in str(x):
            count += 1
        return f' count of digit in {x} is {count}'
    
    def fibo_number(self,x):
        if x == 0 or x== 1:
            return 1
        else:
            return f'fibonaaci series number at {x} position is {(fibo_number(x-1) + fibo_number(x-2))}'
        
    def fibo_series(self,x):
        a = 0
        b = 1
        sum = 0
        for i in range(x):
            sum = a+b
            print(sum)
            a,b = b,sum
            
            
    def area_of_triangle(self,a,b,c):
        s = (a+b+c)/2
        area = (s*(s-a)*(s-b)*(s-c))**(1/2)
        return f'area of triangle is {area}'
    
    def leap_year(self):
        x = int(input('enter the year to check that year is leap or not'))
        if x%400==0:
            return 'leap year'
        elif x%100 != 0 and x%4 == 0:
            return 'leap year'
        else:
            return 'not leap year'
        
        
    def decimal_to_binary(self):
        x = int(input('enter the decimal number to convert it into binary'))
        s = ''
        while x>0:
            rem = x%2
            s += str(rem)
            x = x//2
        return f'binary conversion of {x} is {int(s[::-1])}'
    
    
    def binary_to_octal(self):
        x = input('enter binary number for octal conversion')
        decimal = 0
        octal = ''
        for i in range(len(x)):
            decimal += int((x[i]))*2**(len(x)-1-i)
        while decimal > 0:
            rem = decimal%8
            octal += str(rem)
            decimal = decimal//8
        return f'octal conversion of binary number {x} is {int(octal[::-1])}'
    
    
    def LCM(self,a,b):
        if a<b:
            a,b = b,a
        for i in range(1,b+1):
            if a*i % b == 0:
                return f'LCM of {a},{b} is {a*i}'
            
    def GCD(self,a,b):
        if a<b:
            a,b = b,a
        while True:
            if a%b == 0:
                return f'GCD of {a},{b} is : {b}'
            else:
                a,b = b,a%b
                
            
    def Linear_search(self,x,l=[10,15,20,5,2,6,1]):
        flag = False
        for i in range(len(l)):
            if int(l[i])== x:
                flag = True
            else:
                continue
        if flag:
            return 'x is found in list'
        else:
            return 'x not found in list'
            
    def Binary_search(self,x,l=[10,15,20,5,2,6,1]):
        l.sort()
        mid = len(l)//2
        if l[mid] == x:
            return f'{x} in list'
        elif l[mid] > x:
            return Binary_search(x,l[:mid])
        elif l[mid] < x:
            return Binary_search(x,l[mid+1:])
        else:
            return f'sorry {x} not in list'
        
        
obj = tcs()
# Out:
# wlc to crack tcs coding q using python
